# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from citipy import citipy
import time
from datetime import datetime

# %%
# Create a set of 2000 random latitudes and longitudes 
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# URL for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08f81cd3e1d57e999c5bcecfd72f45d5

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
# If the city is unique, add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 755

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        for i in city_weather['weather']:
            city_description=i["description"]
              
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),"Country": city_country,"Lat": city_lat,"Lng": city_lng,"Max Temp": city_max_temp,"Humidity": city_humidity,"Cloudiness": city_clouds,"Wind Speed": city_wind,"Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | cam ranh
# Processing Record 6 of Set 1 | poros
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | san andres
# Processing Record 12 of Set 1 | chumikan
# Processing Record 13 of Set 1 | daoukro
# Processing Record 14 of Set 1 | poum
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | iqaluit
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | ribeira grande
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | loralai
# Processing Record 22 of Set 1 | wainwright
# Processing Record 23 of Set 1 | esperance
# Processing Record 24 of Set 1 | saint-philippe
# Processing Record 25 of Set 1 | mahebourg
# Processing Record 26 of Set 1 | norwich
# Processing Record 27 of Set 1 | luderitz
# Processing Record 28 of Set 1 | santo domingo
# Processing Record 29 of Set 1 | ponta do sol
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | kruisfontein
# Processing Record 32 of Set 1 | ust-barguzin
# Processing Record 33 of Set 1 | ambilobe
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | jacareacanga
# Processing Record 36 of Set 1 | north bend
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | geraldton
# Processing Record 39 of Set 1 | margate
# Processing Record 40 of Set 1 | lagoa
# Processing Record 41 of Set 1 | kaitangata
# Processing Record 42 of Set 1 | kasongo-lunda
# Processing Record 43 of Set 1 | karratha
# Processing Record 44 of Set 1 | biak
# Processing Record 45 of Set 1 | nueva guinea
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | port hedland
# Processing Record 48 of Set 1 | yerbogachen
# Processing Record 49 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | okhotsk
# Processing Record 2 of Set 2 | bilma
# Processing Record 3 of Set 2 | bonthe
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | porto uniao
# Processing Record 7 of Set 2 | kenai
# Processing Record 8 of Set 2 | rocha
# Processing Record 9 of Set 2 | isangel
# Processing Record 10 of Set 2 | klaksvik
# Processing Record 11 of Set 2 | touros
# Processing Record 12 of Set 2 | kerki
# City not found. Skipping...
# Processing Record 13 of Set 2 | omaruru
# Processing Record 14 of Set 2 | muscat
# Processing Record 15 of Set 2 | hambantota
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | maniitsoq
# Processing Record 21 of Set 2 | tabarqah
# City not found. Skipping...
# Processing Record 22 of Set 2 | harper
# Processing Record 23 of Set 2 | lufilufi
# Processing Record 24 of Set 2 | padang
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | pulandian
# Processing Record 27 of Set 2 | berlevag
# Processing Record 28 of Set 2 | hasaki
# Processing Record 29 of Set 2 | zhangye
# Processing Record 30 of Set 2 | san matias
# Processing Record 31 of Set 2 | cape town
# Processing Record 32 of Set 2 | arraial do cabo
# Processing Record 33 of Set 2 | kieta
# Processing Record 34 of Set 2 | teya
# Processing Record 35 of Set 2 | lompoc
# Processing Record 36 of Set 2 | tilichiki
# Processing Record 37 of Set 2 | andenes
# Processing Record 38 of Set 2 | morgan city
# Processing Record 39 of Set 2 | lorengau
# Processing Record 40 of Set 2 | talmenka
# Processing Record 41 of Set 2 | hilo
# Processing Record 42 of Set 2 | milton
# Processing Record 43 of Set 2 | arman
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | albany
# Processing Record 46 of Set 2 | roald
# Processing Record 47 of Set 2 | clyde river
# Processing Record 48 of Set 2 | tiksi
# Processing Record 49 of Set 2 | tuktoyaktuk
# Processing Record 50 of Set 2 | thinadhoo
# Processing Record 1 of Set 3 | kaeo
# Processing Record 2 of Set 3 | chokurdakh
# Processing Record 3 of Set 3 | timra
# Processing Record 4 of Set 3 | new norfolk
# Processing Record 5 of Set 3 | jiwani
# Processing Record 6 of Set 3 | crab hill
# City not found. Skipping...
# Processing Record 7 of Set 3 | dunedin
# Processing Record 8 of Set 3 | taltal
# Processing Record 9 of Set 3 | suntar
# Processing Record 10 of Set 3 | el ocote
# Processing Record 11 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 3 | torbay
# Processing Record 14 of Set 3 | sumenep
# Processing Record 15 of Set 3 | knysna
# Processing Record 16 of Set 3 | les escoumins
# Processing Record 17 of Set 3 | acari
# Processing Record 18 of Set 3 | hithadhoo
# Processing Record 19 of Set 3 | vardo
# Processing Record 20 of Set 3 | norman wells
# Processing Record 21 of Set 3 | sept-iles
# Processing Record 22 of Set 3 | pevek
# Processing Record 23 of Set 3 | fereydunshahr
# Processing Record 24 of Set 3 | saint-joseph
# Processing Record 25 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 3 | maceio
# Processing Record 27 of Set 3 | dikson
# Processing Record 28 of Set 3 | airai
# Processing Record 29 of Set 3 | mount isa
# Processing Record 30 of Set 3 | necochea
# Processing Record 31 of Set 3 | zhezkazgan
# Processing Record 32 of Set 3 | fortuna
# Processing Record 33 of Set 3 | ilulissat
# Processing Record 34 of Set 3 | east london
# Processing Record 35 of Set 3 | steamboat springs
# Processing Record 36 of Set 3 | kolosovka
# Processing Record 37 of Set 3 | wakkanai
# Processing Record 38 of Set 3 | asyut
# Processing Record 39 of Set 3 | katsuura
# Processing Record 40 of Set 3 | tasiilaq
# Processing Record 41 of Set 3 | homa bay
# Processing Record 42 of Set 3 | bambous virieux
# Processing Record 43 of Set 3 | namibe
# Processing Record 44 of Set 3 | yinchuan
# Processing Record 45 of Set 3 | cherskiy
# Processing Record 46 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 3 | castro
# Processing Record 48 of Set 3 | tanza
# Processing Record 49 of Set 3 | vuktyl
# Processing Record 50 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 4 | provideniya
# Processing Record 2 of Set 4 | vanimo
# Processing Record 3 of Set 4 | butaritari
# Processing Record 4 of Set 4 | oyem
# Processing Record 5 of Set 4 | zmievka
# City not found. Skipping...
# Processing Record 6 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 4 | medford
# Processing Record 8 of Set 4 | leningradskiy
# Processing Record 9 of Set 4 | kidal
# Processing Record 10 of Set 4 | weston
# Processing Record 11 of Set 4 | ust-koksa
# Processing Record 12 of Set 4 | flin flon
# Processing Record 13 of Set 4 | havre
# Processing Record 14 of Set 4 | mayo
# Processing Record 15 of Set 4 | bethel
# Processing Record 16 of Set 4 | upernavik
# Processing Record 17 of Set 4 | fort nelson
# Processing Record 18 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 4 | stornoway
# Processing Record 20 of Set 4 | verkhnevilyuysk
# Processing Record 21 of Set 4 | kavieng
# Processing Record 22 of Set 4 | mar del plata
# Processing Record 23 of Set 4 | cabo san lucas
# Processing Record 24 of Set 4 | lavrentiya
# Processing Record 25 of Set 4 | saldanha
# Processing Record 26 of Set 4 | pochutla
# Processing Record 27 of Set 4 | chapais
# Processing Record 28 of Set 4 | mitsamiouli
# Processing Record 29 of Set 4 | asau
# Processing Record 30 of Set 4 | umm jarr
# City not found. Skipping...
# Processing Record 31 of Set 4 | nome
# Processing Record 32 of Set 4 | sitka
# Processing Record 33 of Set 4 | saskylakh
# Processing Record 34 of Set 4 | vila velha
# Processing Record 35 of Set 4 | lodwar
# Processing Record 36 of Set 4 | hervey bay
# Processing Record 37 of Set 4 | alofi
# Processing Record 38 of Set 4 | bathsheba
# Processing Record 39 of Set 4 | takapau
# Processing Record 40 of Set 4 | zykovo
# Processing Record 41 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 4 | narsaq
# Processing Record 43 of Set 4 | zhanaozen
# Processing Record 44 of Set 4 | bandarbeyla
# Processing Record 45 of Set 4 | pitlochry
# Processing Record 46 of Set 4 | faya
# Processing Record 47 of Set 4 | bengkulu
# Processing Record 48 of Set 4 | kentau
# Processing Record 49 of Set 4 | san alberto
# Processing Record 50 of Set 4 | victoria
# Processing Record 1 of Set 5 | havelock
# Processing Record 2 of Set 5 | jahrom
# City not found. Skipping...
# Processing Record 3 of Set 5 | souillac
# Processing Record 4 of Set 5 | azuaga
# Processing Record 5 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 6 of Set 5 | hami
# Processing Record 7 of Set 5 | malindi
# Processing Record 8 of Set 5 | puerto escondido
# Processing Record 9 of Set 5 | guerrero negro
# Processing Record 10 of Set 5 | pokhara
# Processing Record 11 of Set 5 | bin qirdan
# Processing Record 12 of Set 5 | guelengdeng
# City not found. Skipping...
# Processing Record 13 of Set 5 | grand forks
# Processing Record 14 of Set 5 | nikolskoye
# Processing Record 15 of Set 5 | sistranda
# Processing Record 16 of Set 5 | viedma
# Processing Record 17 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 5 | nhulunbuy
# Processing Record 19 of Set 5 | tual
# Processing Record 20 of Set 5 | axim
# Processing Record 21 of Set 5 | pisco
# Processing Record 22 of Set 5 | poronaysk
# Processing Record 23 of Set 5 | amot
# Processing Record 24 of Set 5 | adrar
# Processing Record 25 of Set 5 | kabinda
# Processing Record 26 of Set 5 | dalvik
# Processing Record 27 of Set 5 | vao
# Processing Record 28 of Set 5 | flinders
# Processing Record 29 of Set 5 | peleduy
# Processing Record 30 of Set 5 | elizabeth city
# Processing Record 31 of Set 5 | yeppoon
# Processing Record 32 of Set 5 | nuuk
# Processing Record 33 of Set 5 | san policarpo
# Processing Record 34 of Set 5 | mattru
# Processing Record 35 of Set 5 | izhma
# Processing Record 36 of Set 5 | trelew
# Processing Record 37 of Set 5 | anadyr
# Processing Record 38 of Set 5 | tromso
# Processing Record 39 of Set 5 | longyearbyen
# Processing Record 40 of Set 5 | mawlaik
# Processing Record 41 of Set 5 | acapulco
# Processing Record 42 of Set 5 | bhopal
# Processing Record 43 of Set 5 | pombas
# Processing Record 44 of Set 5 | port elizabeth
# Processing Record 45 of Set 5 | aanekoski
# Processing Record 46 of Set 5 | mount gambier
# Processing Record 47 of Set 5 | grande-riviere
# City not found. Skipping...
# Processing Record 48 of Set 5 | port blair
# Processing Record 49 of Set 5 | bazpur
# Processing Record 50 of Set 5 | itarema
# Processing Record 1 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 6 | antofagasta
# Processing Record 3 of Set 6 | salinas
# Processing Record 4 of Set 6 | high prairie
# Processing Record 5 of Set 6 | hurghada
# Processing Record 6 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 7 of Set 6 | belyy yar
# Processing Record 8 of Set 6 | mao
# Processing Record 9 of Set 6 | linchuan
# City not found. Skipping...
# Processing Record 10 of Set 6 | college
# Processing Record 11 of Set 6 | rio cuarto
# Processing Record 12 of Set 6 | chicama
# Processing Record 13 of Set 6 | umea
# Processing Record 14 of Set 6 | osa
# Processing Record 15 of Set 6 | pringsewu
# Processing Record 16 of Set 6 | tautira
# Processing Record 17 of Set 6 | minna
# Processing Record 18 of Set 6 | salina
# Processing Record 19 of Set 6 | portmore
# Processing Record 20 of Set 6 | thilogne
# City not found. Skipping...
# Processing Record 21 of Set 6 | seoul
# Processing Record 22 of Set 6 | sladkovo
# Processing Record 23 of Set 6 | belaya gora
# Processing Record 24 of Set 6 | nyanza
# Processing Record 25 of Set 6 | gladstone
# Processing Record 26 of Set 6 | manta
# Processing Record 27 of Set 6 | igarka
# Processing Record 28 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 6 | xai-xai
# Processing Record 30 of Set 6 | los llanos de aridane
# Processing Record 31 of Set 6 | high level
# Processing Record 32 of Set 6 | port alfred
# Processing Record 33 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 34 of Set 6 | pangnirtung
# Processing Record 35 of Set 6 | zhigansk
# Processing Record 36 of Set 6 | karabulak
# Processing Record 37 of Set 6 | tuatapere
# Processing Record 38 of Set 6 | kalemie
# Processing Record 39 of Set 6 | visby
# Processing Record 40 of Set 6 | whakatane
# Processing Record 41 of Set 6 | cabedelo
# Processing Record 42 of Set 6 | tahta
# Processing Record 43 of Set 6 | lampang
# Processing Record 44 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 6 | sorland
# Processing Record 46 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 6 | kinablangan
# Processing Record 48 of Set 6 | doume
# Processing Record 49 of Set 6 | moroni
# Processing Record 50 of Set 6 | daura
# Processing Record 1 of Set 7 | saint anthony
# Processing Record 2 of Set 7 | atbasar
# Processing Record 3 of Set 7 | road town
# Processing Record 4 of Set 7 | srednekolymsk
# Processing Record 5 of Set 7 | betong
# Processing Record 6 of Set 7 | luwuk
# Processing Record 7 of Set 7 | gat
# Processing Record 8 of Set 7 | tukrah
# Processing Record 9 of Set 7 | alyangula
# Processing Record 10 of Set 7 | kouango
# Processing Record 11 of Set 7 | piterka
# Processing Record 12 of Set 7 | panguna
# Processing Record 13 of Set 7 | lebu
# Processing Record 14 of Set 7 | malkara
# Processing Record 15 of Set 7 | marawi
# Processing Record 16 of Set 7 | kassala
# Processing Record 17 of Set 7 | san ramon de la nueva oran
# Processing Record 18 of Set 7 | paracuru
# Processing Record 19 of Set 7 | sterling
# Processing Record 20 of Set 7 | kendari
# Processing Record 21 of Set 7 | uusikaupunki
# Processing Record 22 of Set 7 | shingu
# Processing Record 23 of Set 7 | lagos
# Processing Record 24 of Set 7 | moose factory
# Processing Record 25 of Set 7 | kodiak
# Processing Record 26 of Set 7 | severo-kurilsk
# Processing Record 27 of Set 7 | jabinyanah
# Processing Record 28 of Set 7 | hamilton
# Processing Record 29 of Set 7 | birin
# Processing Record 30 of Set 7 | dingle
# Processing Record 31 of Set 7 | iberia
# Processing Record 32 of Set 7 | bulungu
# Processing Record 33 of Set 7 | faanui
# Processing Record 34 of Set 7 | gamboula
# Processing Record 35 of Set 7 | morondava
# Processing Record 36 of Set 7 | japura
# Processing Record 37 of Set 7 | avera
# Processing Record 38 of Set 7 | waitati
# Processing Record 39 of Set 7 | tupik
# Processing Record 40 of Set 7 | fuengirola
# Processing Record 41 of Set 7 | carballo
# Processing Record 42 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 7 | kungurtug
# Processing Record 44 of Set 7 | yakeshi
# Processing Record 45 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 7 | calama
# Processing Record 47 of Set 7 | burnie
# Processing Record 48 of Set 7 | camacha
# Processing Record 49 of Set 7 | te anau
# Processing Record 50 of Set 7 | san felipe
# Processing Record 1 of Set 8 | chebsara
# Processing Record 2 of Set 8 | buraydah
# Processing Record 3 of Set 8 | shimanovsk
# Processing Record 4 of Set 8 | chuy
# Processing Record 5 of Set 8 | sioux lookout
# Processing Record 6 of Set 8 | palmer
# Processing Record 7 of Set 8 | umm lajj
# Processing Record 8 of Set 8 | buala
# Processing Record 9 of Set 8 | nanortalik
# Processing Record 10 of Set 8 | armacao dos buzios
# City not found. Skipping...
# Processing Record 11 of Set 8 | saint-junien
# Processing Record 12 of Set 8 | litoral del san juan
# City not found. Skipping...
# Processing Record 13 of Set 8 | moiyabana
# City not found. Skipping...
# Processing Record 14 of Set 8 | pathein
# Processing Record 15 of Set 8 | kautokeino
# Processing Record 16 of Set 8 | suhbaatar
# Processing Record 17 of Set 8 | chanthaburi
# Processing Record 18 of Set 8 | bahir dar
# Processing Record 19 of Set 8 | paamiut
# Processing Record 20 of Set 8 | minot
# Processing Record 21 of Set 8 | baiao
# Processing Record 22 of Set 8 | gewane
# Processing Record 23 of Set 8 | raudeberg
# Processing Record 24 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 8 | kosh-agach
# Processing Record 26 of Set 8 | cayenne
# Processing Record 27 of Set 8 | cap malheureux
# Processing Record 28 of Set 8 | zhanakorgan
# Processing Record 29 of Set 8 | zlatoustovsk
# City not found. Skipping...
# Processing Record 30 of Set 8 | nishihara
# Processing Record 31 of Set 8 | meulaboh
# Processing Record 32 of Set 8 | kushiro
# Processing Record 33 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 34 of Set 8 | lubao
# Processing Record 35 of Set 8 | banavar
# Processing Record 36 of Set 8 | emerald
# Processing Record 37 of Set 8 | shiringushi
# Processing Record 38 of Set 8 | ilhabela
# Processing Record 39 of Set 8 | kasempa
# Processing Record 40 of Set 8 | sao joao da barra
# Processing Record 41 of Set 8 | bonavista
# Processing Record 42 of Set 8 | guasdualito
# Processing Record 43 of Set 8 | portland
# Processing Record 44 of Set 8 | mandalgovi
# Processing Record 45 of Set 8 | taksimo
# Processing Record 46 of Set 8 | bousso
# Processing Record 47 of Set 8 | ust-ishim
# Processing Record 48 of Set 8 | xinqing
# Processing Record 49 of Set 8 | vestmannaeyjar
# Processing Record 50 of Set 8 | okandja
# City not found. Skipping...
# Processing Record 1 of Set 9 | vasterhaninge
# Processing Record 2 of Set 9 | collie
# Processing Record 3 of Set 9 | shu
# Processing Record 4 of Set 9 | itaituba
# Processing Record 5 of Set 9 | cockburn town
# Processing Record 6 of Set 9 | puerto baquerizo moreno
# Processing Record 7 of Set 9 | coetupo
# City not found. Skipping...
# Processing Record 8 of Set 9 | beringovskiy
# Processing Record 9 of Set 9 | popondetta
# Processing Record 10 of Set 9 | bernal
# Processing Record 11 of Set 9 | hofn
# Processing Record 12 of Set 9 | zemio
# Processing Record 13 of Set 9 | manadhoo
# Processing Record 14 of Set 9 | husavik
# Processing Record 15 of Set 9 | kurduvadi
# Processing Record 16 of Set 9 | taoudenni
# Processing Record 17 of Set 9 | nadym
# Processing Record 18 of Set 9 | tim
# Processing Record 19 of Set 9 | ostrovnoy
# Processing Record 20 of Set 9 | sambava
# Processing Record 21 of Set 9 | monrovia
# Processing Record 22 of Set 9 | port shepstone
# Processing Record 23 of Set 9 | andra
# Processing Record 24 of Set 9 | nelson bay
# Processing Record 25 of Set 9 | vostok
# Processing Record 26 of Set 9 | saint george
# Processing Record 27 of Set 9 | pasni
# Processing Record 28 of Set 9 | winona
# Processing Record 29 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 9 | maxixe
# Processing Record 31 of Set 9 | wagar
# Processing Record 32 of Set 9 | sestri levante
# Processing Record 33 of Set 9 | sao filipe
# Processing Record 34 of Set 9 | morant bay
# Processing Record 35 of Set 9 | nanton
# Processing Record 36 of Set 9 | salalah
# Processing Record 37 of Set 9 | tura
# Processing Record 38 of Set 9 | verkhnyaya inta
# Processing Record 39 of Set 9 | butembo
# Processing Record 40 of Set 9 | cururupu
# Processing Record 41 of Set 9 | mount darwin
# Processing Record 42 of Set 9 | talaya
# Processing Record 43 of Set 9 | birjand
# Processing Record 44 of Set 9 | san patricio
# Processing Record 45 of Set 9 | honiara
# Processing Record 46 of Set 9 | shenjiamen
# Processing Record 47 of Set 9 | moerai
# Processing Record 48 of Set 9 | santa vitoria do palmar
# Processing Record 49 of Set 9 | zabid
# Processing Record 50 of Set 9 | yulara
# Processing Record 1 of Set 10 | vargem grande do sul
# Processing Record 2 of Set 10 | bykivka
# Processing Record 3 of Set 10 | bilibino
# Processing Record 4 of Set 10 | ahipara
# Processing Record 5 of Set 10 | talnakh
# Processing Record 6 of Set 10 | sao jose da coroa grande
# Processing Record 7 of Set 10 | ngaoundere
# Processing Record 8 of Set 10 | kushikino
# Processing Record 9 of Set 10 | sao joao
# Processing Record 10 of Set 10 | sundsvall
# Processing Record 11 of Set 10 | badou
# Processing Record 12 of Set 10 | kirakira
# Processing Record 13 of Set 10 | pitiquito
# Processing Record 14 of Set 10 | anito
# Processing Record 15 of Set 10 | kuandian
# Processing Record 16 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 10 | mariel
# Processing Record 18 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 10 | szentistvan
# Processing Record 20 of Set 10 | antalaha
# Processing Record 21 of Set 10 | nago
# Processing Record 22 of Set 10 | praia da vitoria
# Processing Record 23 of Set 10 | phangnga
# Processing Record 24 of Set 10 | chernyshevskiy
# Processing Record 25 of Set 10 | eureka
# Processing Record 26 of Set 10 | podkletnoye
# Processing Record 27 of Set 10 | ryotsu
# Processing Record 28 of Set 10 | griffith
# Processing Record 29 of Set 10 | potosi
# Processing Record 30 of Set 10 | shubarshi
# Processing Record 31 of Set 10 | andapa
# Processing Record 32 of Set 10 | shimoda
# Processing Record 33 of Set 10 | ingham
# Processing Record 34 of Set 10 | rawson
# Processing Record 35 of Set 10 | chanika
# Processing Record 36 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 37 of Set 10 | khorixas
# Processing Record 38 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 10 | baker city
# Processing Record 40 of Set 10 | behshahr
# Processing Record 41 of Set 10 | broome
# Processing Record 42 of Set 10 | kedrovyy
# Processing Record 43 of Set 10 | tangjiazhuang
# Processing Record 44 of Set 10 | uribia
# Processing Record 45 of Set 10 | nancha
# Processing Record 46 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 47 of Set 10 | helong
# Processing Record 48 of Set 10 | coulihaut
# City not found. Skipping...
# Processing Record 49 of Set 10 | half moon bay
# Processing Record 50 of Set 10 | coquimbo
# Processing Record 1 of Set 11 | muros
# Processing Record 2 of Set 11 | lunavada
# Processing Record 3 of Set 11 | oktyabrskiy
# Processing Record 4 of Set 11 | berdigestyakh
# Processing Record 5 of Set 11 | labuan
# Processing Record 6 of Set 11 | vaitape
# Processing Record 7 of Set 11 | ust-tsilma
# Processing Record 8 of Set 11 | bhadrak
# Processing Record 9 of Set 11 | pimentel
# Processing Record 10 of Set 11 | posadas
# Processing Record 11 of Set 11 | aitape
# Processing Record 12 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 11 | grenaa
# Processing Record 14 of Set 11 | tchibanga
# Processing Record 15 of Set 11 | lebedinyy
# Processing Record 16 of Set 11 | saint-augustin
# Processing Record 17 of Set 11 | muhos
# Processing Record 18 of Set 11 | aguadilla
# Processing Record 19 of Set 11 | zilair
# Processing Record 20 of Set 11 | neuquen
# Processing Record 21 of Set 11 | ekibastuz
# Processing Record 22 of Set 11 | oyama
# Processing Record 23 of Set 11 | huarmey
# Processing Record 24 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 25 of Set 11 | salta
# Processing Record 26 of Set 11 | san cristobal
# Processing Record 27 of Set 11 | bereda
# Processing Record 28 of Set 11 | biu
# Processing Record 29 of Set 11 | druskininkai
# Processing Record 30 of Set 11 | gejiu
# Processing Record 31 of Set 11 | babstovo
# Processing Record 32 of Set 11 | umm kaddadah
# Processing Record 33 of Set 11 | seidu
# Processing Record 34 of Set 11 | pueblo nuevo
# Processing Record 35 of Set 11 | ayan
# Processing Record 36 of Set 11 | hokitika
# Processing Record 37 of Set 11 | lasa
# Processing Record 38 of Set 11 | bubaque
# Processing Record 39 of Set 11 | vanavara
# Processing Record 40 of Set 11 | port-gentil
# Processing Record 41 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 42 of Set 11 | labuhan
# Processing Record 43 of Set 11 | goma
# Processing Record 44 of Set 11 | saint-pierre
# Processing Record 45 of Set 11 | kahama
# Processing Record 46 of Set 11 | cap-aux-meules
# Processing Record 47 of Set 11 | safwah
# City not found. Skipping...
# Processing Record 48 of Set 11 | biltine
# Processing Record 49 of Set 11 | kita
# Processing Record 50 of Set 11 | babayurt
# Processing Record 1 of Set 12 | straumen
# Processing Record 2 of Set 12 | evensk
# Processing Record 3 of Set 12 | ozimek
# Processing Record 4 of Set 12 | yaring
# Processing Record 5 of Set 12 | takoradi
# Processing Record 6 of Set 12 | beipiao
# Processing Record 7 of Set 12 | carson city
# Processing Record 8 of Set 12 | chhapar
# Processing Record 9 of Set 12 | kangaatsiaq
# Processing Record 10 of Set 12 | talcahuano
# Processing Record 11 of Set 12 | cape canaveral
# Processing Record 12 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 12 | coihaique
# Processing Record 14 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 15 of Set 12 | manggar
# Processing Record 16 of Set 12 | gravdal
# Processing Record 17 of Set 12 | jalu
# Processing Record 18 of Set 12 | garden city
# Processing Record 19 of Set 12 | san quintin
# Processing Record 20 of Set 12 | westport
# Processing Record 21 of Set 12 | nouadhibou
# Processing Record 22 of Set 12 | sola
# Processing Record 23 of Set 12 | kununurra
# Processing Record 24 of Set 12 | ancud
# Processing Record 25 of Set 12 | buin
# Processing Record 26 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 27 of Set 12 | mopipi
# Processing Record 28 of Set 12 | maracacume
# Processing Record 29 of Set 12 | mayor pablo lagerenza
# Processing Record 30 of Set 12 | poya
# Processing Record 31 of Set 12 | beyneu
# Processing Record 32 of Set 12 | hongjiang
# Processing Record 33 of Set 12 | glendive
# Processing Record 34 of Set 12 | acarau
# Processing Record 35 of Set 12 | ishigaki
# Processing Record 36 of Set 12 | iquitos
# Processing Record 37 of Set 12 | santa maria
# Processing Record 38 of Set 12 | bardiyah
# Processing Record 39 of Set 12 | russell
# Processing Record 40 of Set 12 | yar-sale
# Processing Record 41 of Set 12 | camalu
# Processing Record 42 of Set 12 | suclayin
# Processing Record 43 of Set 12 | berezovyy
# Processing Record 44 of Set 12 | naze
# Processing Record 45 of Set 12 | bontang
# Processing Record 46 of Set 12 | samarai
# Processing Record 47 of Set 12 | carman
# Processing Record 48 of Set 12 | hovd
# Processing Record 49 of Set 12 | kiruna
# Processing Record 50 of Set 12 | gigmoto
# Processing Record 1 of Set 13 | sorong
# Processing Record 2 of Set 13 | najran
# Processing Record 3 of Set 13 | kamenka
# Processing Record 4 of Set 13 | apomu
# Processing Record 5 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 6 of Set 13 | kurilsk
# Processing Record 7 of Set 13 | kahului
# Processing Record 8 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 9 of Set 13 | sur
# Processing Record 10 of Set 13 | rongcheng
# Processing Record 11 of Set 13 | lukoyanov
# Processing Record 12 of Set 13 | sakassou
# Processing Record 13 of Set 13 | porto novo
# Processing Record 14 of Set 13 | huangmei
# Processing Record 15 of Set 13 | altay
# Processing Record 16 of Set 13 | port lincoln
# Processing Record 17 of Set 13 | kalininsk
# Processing Record 18 of Set 13 | rio gallegos
# Processing Record 19 of Set 13 | along
# Processing Record 20 of Set 13 | cookeville
# Processing Record 21 of Set 13 | nambucca heads
# Processing Record 22 of Set 13 | svetlyy
# Processing Record 23 of Set 13 | talara
# Processing Record 24 of Set 13 | magdagachi
# Processing Record 25 of Set 13 | maltahohe
# Processing Record 26 of Set 13 | staryy biser
# City not found. Skipping...
# Processing Record 27 of Set 13 | kasra
# City not found. Skipping...
# Processing Record 28 of Set 13 | karpogory
# Processing Record 29 of Set 13 | batagay-alyta
# Processing Record 30 of Set 13 | ko samui
# Processing Record 31 of Set 13 | yantal
# Processing Record 32 of Set 13 | teguldet
# Processing Record 33 of Set 13 | innisfail
# Processing Record 34 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 35 of Set 13 | aiken
# Processing Record 36 of Set 13 | fairbanks
# Processing Record 37 of Set 13 | nieuwpoort
# Processing Record 38 of Set 13 | fryanovo
# Processing Record 39 of Set 13 | kalabo
# Processing Record 40 of Set 13 | nalut
# Processing Record 41 of Set 13 | kattivakkam
# Processing Record 42 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 13 | karasjok
# Processing Record 44 of Set 13 | santona
# Processing Record 45 of Set 13 | west wendover
# Processing Record 46 of Set 13 | carutapera
# Processing Record 47 of Set 13 | mhango
# Processing Record 48 of Set 13 | lukovit
# Processing Record 49 of Set 13 | teguise
# Processing Record 50 of Set 13 | sabha
# Processing Record 1 of Set 14 | morag
# Processing Record 2 of Set 14 | aransas pass
# Processing Record 3 of Set 14 | sabang
# Processing Record 4 of Set 14 | homer
# Processing Record 5 of Set 14 | otradnoye
# Processing Record 6 of Set 14 | kysyl-syr
# Processing Record 7 of Set 14 | nushki
# Processing Record 8 of Set 14 | zhuhai
# Processing Record 9 of Set 14 | tulsipur
# Processing Record 10 of Set 14 | urumqi
# Processing Record 11 of Set 14 | paita
# Processing Record 12 of Set 14 | alta floresta
# Processing Record 13 of Set 14 | inirida
# Processing Record 14 of Set 14 | ahuimanu
# Processing Record 15 of Set 14 | cidreira
# Processing Record 16 of Set 14 | batemans bay
# Processing Record 17 of Set 14 | olafsvik
# Processing Record 18 of Set 14 | jiangyou
# Processing Record 19 of Set 14 | san esteban
# Processing Record 20 of Set 14 | henties bay
# Processing Record 21 of Set 14 | la baule-escoublac
# Processing Record 22 of Set 14 | yankton
# Processing Record 23 of Set 14 | maragogi
# Processing Record 24 of Set 14 | mapiripan
# Processing Record 25 of Set 14 | yabelo
# Processing Record 26 of Set 14 | semey
# Processing Record 27 of Set 14 | aklavik
# Processing Record 28 of Set 14 | beloha
# Processing Record 29 of Set 14 | kloulklubed
# Processing Record 30 of Set 14 | pangkalanbuun
# Processing Record 31 of Set 14 | leshukonskoye
# Processing Record 32 of Set 14 | zheshart
# Processing Record 33 of Set 14 | dalbandin
# Processing Record 34 of Set 14 | kalmunai
# Processing Record 35 of Set 14 | grootfontein
# Processing Record 36 of Set 14 | pishchanka
# City not found. Skipping...
# Processing Record 37 of Set 14 | chippewa falls
# Processing Record 38 of Set 14 | roma
# Processing Record 39 of Set 14 | tazovskiy
# Processing Record 40 of Set 14 | korla
# Processing Record 41 of Set 14 | mnogovershinnyy
# Processing Record 42 of Set 14 | ameca
# Processing Record 43 of Set 14 | haines junction
# Processing Record 44 of Set 14 | acajutla
# Processing Record 45 of Set 14 | halifax
# Processing Record 46 of Set 14 | promissao
# Processing Record 47 of Set 14 | caravelas
# Processing Record 48 of Set 14 | ganzhou
# Processing Record 49 of Set 14 | tarangnan
# Processing Record 50 of Set 14 | shache
# Processing Record 1 of Set 15 | charagua
# Processing Record 2 of Set 15 | ulladulla
# Processing Record 3 of Set 15 | atambua
# Processing Record 4 of Set 15 | gilbues
# Processing Record 5 of Set 15 | gornopravdinsk
# Processing Record 6 of Set 15 | independencia
# Processing Record 7 of Set 15 | gondanglegi
# Processing Record 8 of Set 15 | broken hill
# Processing Record 9 of Set 15 | kharp
# Processing Record 10 of Set 15 | banjar
# Processing Record 11 of Set 15 | fukue
# Processing Record 12 of Set 15 | tongren
# Processing Record 13 of Set 15 | grindavik
# Processing Record 14 of Set 15 | turkmenabat
# Processing Record 15 of Set 15 | maryville
# Processing Record 16 of Set 15 | sinnamary
# Processing Record 17 of Set 15 | kisangani
# Processing Record 18 of Set 15 | ambon
# Processing Record 19 of Set 15 | vinzili
# Processing Record 20 of Set 15 | artyom
# Processing Record 21 of Set 15 | salinopolis
# Processing Record 22 of Set 15 | ushirombo
# Processing Record 23 of Set 15 | macas
# Processing Record 24 of Set 15 | novopskov
# Processing Record 25 of Set 15 | teahupoo
# Processing Record 26 of Set 15 | camacupa
# Processing Record 27 of Set 15 | agadez
# Processing Record 28 of Set 15 | tenabo
# Processing Record 29 of Set 15 | kesova gora
# Processing Record 30 of Set 15 | roebourne
# Processing Record 31 of Set 15 | auki
# Processing Record 32 of Set 15 | port-cartier
# Processing Record 33 of Set 15 | la ronge
# Processing Record 34 of Set 15 | nantucket
# Processing Record 35 of Set 15 | matara
# Processing Record 36 of Set 15 | sibolga
# Processing Record 37 of Set 15 | westerville
# Processing Record 38 of Set 15 | port hardy
# Processing Record 39 of Set 15 | nabul
# City not found. Skipping...
# Processing Record 40 of Set 15 | limot
# Processing Record 41 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 42 of Set 15 | argostolion
# Processing Record 43 of Set 15 | belmonte
# Processing Record 44 of Set 15 | am timan
# Processing Record 45 of Set 15 | longonjo
# Processing Record 46 of Set 15 | borogontsy
# Processing Record 47 of Set 15 | araguatins
# City not found. Skipping...
# Processing Record 48 of Set 15 | kingaroy
# Processing Record 49 of Set 15 | regina
# Processing Record 50 of Set 15 | mahon
# Processing Record 1 of Set 16 | aguimes
# Processing Record 2 of Set 16 | sungaipenuh
# Processing Record 3 of Set 16 | ridgecrest
# Processing Record 4 of Set 16 | apatou
# Processing Record 5 of Set 16 | arcata
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Mataura      NZ -46.1927  168.8643     42.48        65           0
# 1      Atuona      PF  -9.8000 -139.0333     78.08        78          23
# 2       Vaini      TO -21.2000 -175.2000     78.96        83          75
# 3    Cam Ranh      VN  11.9214  109.1591     91.36        52           0
# 4       Poros      GR  37.4994   23.4536     72.91        64           0
# 5    Khatanga      RU  71.9667  102.5000     53.69        59         100
# 6   Busselton      AU -33.6500  115.3333     63.57        69         100
# 7   Carnarvon      AU -24.8667  113.6333     69.84        50           0
# 8  San Andres      CO  12.5847  -81.7006     82.42        78          40
# 9    Chumikan      RU  54.7183  135.3150     48.09        79          24
#
#    Wind Speed Current Description
# 0        1.83           clear sky
# 1       22.32          few clouds
# 2       11.50       broken clouds
# 3        2.30           clear sky
# 4        4.94           clear sky
# 5       10.92     overcast clouds
# 6       13.91     overcast clouds
# 7       12.01           clear sky
# 8       13.80        thunderstorm
# 9       11.59          few clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
